# %% [markdown]
# # Plot Spectrum CO56

# %%
#Import required packages

import numpy as np
import pandas as pd
#pd.set_option('float_format', '{:f}'.format)
#pd.options.display.float_format = "{:.2f}".format
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import colors
# %matplotlib inline

# %%
df_CO56 = pd.read_csv('Spectrum_CIRES_Station_CO56.csv')

# %%
df_CO56
# Out:
#      Time (s)   CO56-NS   CO56-EW
# 0        0.00       NaN       NaN
# 1        0.01       NaN       NaN
# 2        0.02  0.112281  0.116681
# 3        0.03  0.112026  0.116451
# 4        0.04  0.112710  0.117874
# ..        ...       ...       ...
# 495      4.95  0.019305  0.025706
# 496      4.96  0.019301  0.025441
# 497      4.97  0.019292  0.025439
# 498      4.98  0.019276  0.025433
# 499      4.99  0.019254  0.025422
#
# [500 rows x 3 columns]

# %%
df_CO56.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Time (s)  500 non-null    float64
#  1   CO56-NS   498 non-null    float64
#  2   CO56-EW   498 non-null    float64
# dtypes: float64(3)
# memory usage: 11.8 KB

# %%
x_x=[1.512,1.512]
y_y=[0.0,0.24]

x_x2=[0,1.512]
y_y2=[0.240,0.240]

#fig, ax = plt.subplots()
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

ax.plot(df_CO56['Time (s)'], df_CO56['CO56-NS'], lw=4, c='blue', label='CO56-NorthSouth')
ax.plot(df_CO56['Time (s)'], df_CO56['CO56-EW'], lw=4, c='orange', label='CO56-EastWest')

ax.plot(x_x, y_y, lw=4, c='green')
ax.plot(x_x2, y_y2, lw=4, c='green')

ax.set_xlim(0,5)
ax.set_ylim(0,0.5)

ax.tick_params(axis="x", labelsize=24)
ax.tick_params(axis="y", labelsize=24)

ax.set_xlabel(r'Period $T_1$ (s)', fontsize = 24, labelpad=10)
ax.set_ylabel('Spectral acceleration (g)', fontsize = 24, labelpad=10)

ax.grid(linewidth=1)

ax.legend()
ax.legend(loc=1,prop={'size': 20})  #to make legend bold

plt.show()

# %%
# Export figure
#fig.savefig("/homevol/sroe459/Data/spectrum_CO56.png", dpi=600)
